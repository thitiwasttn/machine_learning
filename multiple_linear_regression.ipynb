# %% [markdown]
# <a href="https://colab.research.google.com/github/thitiwasttn/machine_learning/blob/main/multiple_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('/content/Advertising.csv', index_col=0)
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
sns.pairplot(df, x_vars=['TV', 'Radio', 'Newspaper'], y_vars='Sales', height=4)

# %%
sns.pairplot(df, x_vars=['TV', 'Radio', 'Newspaper'], y_vars='Sales', height=4, kind='reg')

# %%
g = sns.pairplot(df)
g.fig.set_size_inches(9,9)

# %% [markdown]
# create model

# %%
feature_cols = ['TV','Radio','Newspaper']
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

model = LinearRegression()
model.fit(X_train,y_train)

model.coef_ , model.intercept_
# Out:
# (array([ 0.04,  0.2 , -0.  ]), 2.994893030495332)

# %%
model.score(X_train, y_train), model.score(X_test, y_test)
# Out:
# (0.9067114990146382, 0.8601145185017868)

# %%
X_test
# Out:
# array([[ 69.2,  20.5,  18.3],
#        [ 50. ,  11.6,  18.4],
#        [ 90.4,   0.3,  23.2],
#        [289.7,  42.3,  51.2],
#        [170.2,   7.8,  35.2],
#        [ 56.2,   5.7,  29.7],
#        [  8.7,  48.9,  75. ],
#        [240.1,   7.3,   8.7],
#        [ 23.8,  35.1,  65.9],
#        [197.6,  23.3,  14.2],
#        [261.3,  42.7,  54.7],
#        [ 87.2,  11.8,  25.9],
#        [156.6,   2.6,   8.3],
#        [187.8,  21.1,   9.5],
#        [ 76.4,  26.7,  22.3],
#        [120.2,  19.6,  11.6],
#        [265.6,  20. ,   0.3],
#        [  0.7,  39.6,   8.7],
#        [ 74.7,  49.4,  45.7],
#        [213.4,  24.6,  13.1],
#        [287.6,  43. ,  71.8],
#        [140.3,   1.9,   9. ],
#        [175.1,  22.5,  31.5],
#        [131.7,  18.4,  34.6],
#        [ 53.5,   2. ,  21.4],
#        [123.1,  34.6,  12.4],
#        [165.6,  10. ,  17.6],
#        [205. ,  45.1,  19.6],
#        [224. ,   2.4,  15.6],
#        [ 25.1,  25.7,  43.3],
#        [ 67.8,  36.6, 114. ],
# ...

# %%
x_input = [[230, 37, 69]]
y_pred = model.predict(X_test)
y_pred
# Out:
# array([10.06,  7.45,  7.02, 24.08, 12.02,  6.54, 12.78, 15.11, 10.77,
#        16.34, 22.88,  9.13, 10.46, 15.49, 11.59, 12.17, 18.77, 10.78,
#        15.91, 17.31, 24.07,  9.6 , 15.14, 12.39,  5.71, 15.25, 12.29,
#        20.94, 13.41,  9.04, 12.89, 21.4 , 18.14, 21.17,  6.57,  6.14,
#         7.89, 13.02, 14.69,  6.19])
